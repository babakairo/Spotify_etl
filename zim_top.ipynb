# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

client_credentials_manager = SpotifyClientCredentials(client_id = "918287b7494f4568a024a47342c8b56f", client_secret="4ecba3c9a9fb49439b936ceac13bc897")
sp = spotipy.Spotify(client_credentials_manager= client_credentials_manager)

global_top = 'https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF'
list = (global_top.split('/'))
global_top_url = list[4]
print(global_top_url)

print(sp.playlist_tracks(global_top_url))
# Out:
# 37i9dQZEVXbNG2KDcFcKOF
# ...

# %%
data = sp.playlist_tracks(global_top_url)

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    
    album_element = {'album_id': album_id, 'name': album_name,'release_date': album_release_date,
                     'total_tracks':album_total_tracks, 'url': album_url}
    
    album_list.append(album_element)

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_name': artist['name'], 'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_popularity = row['track']['popularity']
    song_url = row['track']['album']['external_urls']['spotify']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_dict = {
    'song_id': song_id,
    'song_name': song_name,
    'song_duration': song_duration,
    'song_popularity': song_popularity,
    'song_url': song_url,
    'song_added': song_added,
    'album_id': album_id,
    'artist_id': artist_id
    }
    song_list.append(song_dict)

# %%
album_df = pd.DataFrame.from_dict(album_list)
song_df = pd.DataFrame.from_dict(song_list)
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date']).dt.date

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added']).dt.date

# %%
song_df.head()
# Out:
#                   song_id             song_name  song_duration  \
# 0  2qSkIjg1o9h3YT9RAgYN75              Espresso         175459
# 1  6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER         210373
# 2  5N3hjp1WNayUPZrA8kJmJP  Please Please Please         186365
# 3  6AI3ezQ4o3HUoP6Dhudph3           Not Like Us         274192
# 4  6XjDF6nds4DE2BBbagZol6             Gata Only         222000
#
#    song_popularity                                           song_url  \
# 0               99  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 1               99  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2               98  https://open.spotify.com/album/5bBaoign62r1i7O...
# 3               97  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 4               96  https://open.spotify.com/album/5tSQtQGkrCJx3ho...
#
#    song_added                album_id               artist_id
# 0  2024-07-12  5quMTd5zeI9yW5UDua8wS4  74KM79TiuVKeVCqs8QtB0B
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB
