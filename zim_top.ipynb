# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id = "918287b7494f4568a024a47342c8b56f", client_secret="4ecba3c9a9fb49439b936ceac13bc897")
sp = spotipy.Spotify(client_credentials_manager= client_credentials_manager)

zim_top = 'https://open.spotify.com/playlist/62pclye6xpbTx1idsqACM8'
list = (zim_top.split('/'))
zim_top_url = list[4]
print(zim_top_url)

print(sp.playlist_tracks(zim_top_url))
# Out:
# 62pclye6xpbTx1idsqACM8
# ...

# %% [markdown]
# data = sp.playlist_tracks(zim_top_url)

# %%
data['items']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data['items']
#
# NameError: name 'data' is not defined
